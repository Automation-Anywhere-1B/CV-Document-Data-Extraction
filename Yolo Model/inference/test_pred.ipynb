# %%
from yolo_model import Yolo_Detection
import matplotlib

# %%
model = Yolo_Detection('best.pt')

# %%
model.predict('check.jpeg')
plt.show(model.visualize_prediction())
# Out:
# image 1/1 c:\Users\gurno\Downloads\Projects\Breakthrough Tech Project\Yolo Model\inference\check.jpeg: 288x640 1 amount, 1 date, 2 payees, 1 signature_g, 26.3ms
# Speed: 3.8ms preprocess, 26.3ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 model.predict('check.jpeg')
# ----> 2 plt.show(model.visualize_prediction())
#
# NameError: name 'plt' is not defined
