# %%
import os
import matplotlib.pyplot as plt
from inference.resnet_model import Resnet_Classifier

# %%
BEST = "resnet_best_weights_4.pth"

# %%
path = f"train/{BEST}";

model = Resnet_Classifier(path)

# %%
model.visualize_model_predictions("example.png")
