# %%
import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
from inference.yolo_model import Yolo_Detection

# %%
BEST = "train2"

# %%
path = f"training/runs/detect/{BEST}/weights/best.pt";

model = Yolo_Detection(path)

# %%
model.predict('check.jpg')
plt.imshow(model.visualize_prediction())
plt.axis("off")
plt.show()
# Out:
# 0: 288x640 1 signature, 1 amount, 1 amount_words, 1 date, 2 payees, 70.2ms
# Speed: 2.3ms preprocess, 70.2ms inference, 7.4ms postprocess per image at shape (1, 3, 288, 640)
