# %%
import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
from inference.yolo_model import Yolo_Detection

# %%
BEST = "train2"

# %%
path = f"training/runs/detect/{BEST}/weights/best.pt";

model = Yolo_Detection(path)

# %%
model.predict('check.jpg')
model.visualize_last_prediction()
# Out:
# 0: 288x640 1 signature, 1 amount, 1 amount_words, 1 date, 2 payees, 64.8ms
# Speed: 19.1ms preprocess, 64.8ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 640)

# %%
model.predict(['check.jpg', 'check2.jpg'])
# Out:
# 0: 640x640 1 signature, 1 amount, 1 amount_words, 1 date, 3 payees, 30.1ms
# 1: 640x640 1 payee, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'signature', 1: 'amount', 2: 'amount_words', 3: 'date', 4: 'payee', 5: 'signature_f', 6: 'signature_g'}
#  obb: None
#  orig_img: array([[[245, 244, 246],
#          [255, 254, 255],
#          [254, 253, 255],
#          ...,
#          [255, 251, 255],
#          [255, 253, 255],
#          [249, 247, 246]],
#
#         [[255, 254, 255],
#          [244, 245, 243],
#          [253, 255, 251],
#          ...,
#          [248, 246, 245],
#          [248, 246, 245],
#          [255, 255, 254]],
#
#         [[251, 250, 254],
#          [249, 253, 247],
#          [249, 255, 240],
#          ...,
#          [253, 255, 245],
#          [253, 255, 249],
#          [251, 252, 250]],
#
#         ...,
#
#         [[253, 255, 255],
#          [253, 255, 255],
#          [252, 254, 254],
#          ...,
#          [253, 255, 255],
#          [253, 255, 255],
#          [253, 255, 255]],
#
#         [[253, 255, 255],
#          [253, 255, 255],
#          [252, 254, 254],
#          ...,
#          [253, 255, 255],
#          [253, 255, 255],
#          [253, 255, 255]],
#
#         [[252, 254, 254],
#          [252, 254, 254],
#          [253, 255, 255],
#          ...,
#          [253, 255, 255],
#          [253, 255, 255],
#          [252, 254, 254]]], shape=(360, 847, 3), dtype=uint8)
#  orig_shape: (360, 847)
#  path: 'check.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\gurno\\Downloads\\Projects\\Breakthrough Tech Project\\Yolo Stacked\\yolo\\runs\\detect\\predict'
#  speed: {'preprocess': 2.01119999974253, 'inference': 30.142850000174803, 'postprocess': 2.805099999932281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'signature', 1: 'amount', 2: 'amount_words', 3: 'date', 4: 'payee', 5: 'signature_f', 6: 'signature_g'}
#  obb: None
#  orig_img: array([[[235, 237, 215],
#          [239, 240, 230],
#          [236, 239, 253],
#          ...,
#          [230, 229, 255],
#          [235, 241, 236],
#          [233, 245, 223]],
#
#         [[255, 255, 248],
#          [252, 254, 255],
#          [207, 211, 236],
#          ...,
#          [214, 210, 245],
#          [248, 253, 254],
#          [247, 255, 242]],
#
#         [[217, 221, 232],
#          [200, 204, 228],
#          [ 99, 103, 151],
#          ...,
#          [115, 111, 160],
#          [205, 208, 223],
#          [212, 220, 219]],
#
#         ...,
#
#         [[202, 213, 235],
#          [198, 206, 235],
#          [102, 107, 146],
#          ...,
#          [100, 104, 163],
#          [197, 202, 251],
#          [201, 207, 252]],
#
#         [[241, 253, 255],
#          [239, 252, 255],
#          [209, 216, 243],
#          ...,
#          [196, 203, 252],
#          [234, 242, 255],
#          [233, 242, 255]],
#
#         [[213, 227, 225],
#          [220, 235, 238],
#          [225, 234, 248],
#          ...,
#          [211, 223, 255],
#          [213, 224, 254],
#          [207, 220, 246]]], shape=(1253, 3528, 3), dtype=uint8)
#  orig_shape: (1253, 3528)
#  path: 'check2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\gurno\\Downloads\\Projects\\Breakthrough Tech Project\\Yolo Stacked\\yolo\\runs\\detect\\predict'
#  speed: {'preprocess': 2.01119999974253, 'inference': 30.142850000174803, 'postprocess': 2.805099999932281}]

# %%
model.visualize_last_prediction()

# %%
model.visualize_all_predictions()
